# %%
import pandas as pd
pd.set_option('display.max_rows', None)
def search_for(nome, unit=None):
    in_name = df['Nome'].str.contains(nome)
    in_comune = df['Comune'].str.contains(nome)
    mydf = df[in_name | in_comune]
    return mydf if unit is None else mydf[mydf['Strumento'] == unit]
df = pd.read_csv('../../data/geo/stazioni.csv', ';')

# %%
search_for('Simignano')
# Out:
#        IDStazione  StazioneExtra       Nome     Comune Provincia Fiume  \
# 2300  TOS01001379              0  Simignano  Sovicille        SI   NaN
#
#         Strumento Unita' Misura  IDSensoreRete   LAT [o]    LON [o]  \
# 2300  pluviometro            mm       744107.0  43.29205  11.167234
#
#        GB E [m]    GB N [m]  Quota  QuotaTerra
# 2300  1675841.2  4795543.72  420.0         2.0

# %%
search_for('Siena Poggio al Vento', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra                   Nome Comune Provincia  \
# 2298  TOS01002661              0  Siena Poggio al Vento  Siena        SI
#
#      Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 2298   NaN  pluviometro            mm       754107.0  43.320448  11.312592
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 2298  1687546.02  4799013.84  348.0         NaN

# %%
search_for('Siena Poggio al Vento', 'termometro')
# Out:
#        IDStazione  StazioneExtra                   Nome Comune Provincia  \
# 2299  TOS01002661              0  Siena Poggio al Vento  Siena        SI
#
#      Fiume   Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 2299   NaN  termometro            �C       754101.0  43.320448  11.312592
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 2299  1687546.02  4799013.84  348.0         NaN

# %%
search_for('Mensano', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra     Nome         Comune Provincia Fiume  \
# 1184  TOS03001385              0  Mensano  Casole d'Elsa        SI   NaN
# 1185  TOS03001385              0  Mensano  Casole d'Elsa        SI   NaN
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1184  pluviometro            mm       748257.0  43.291376  11.071148
# 1185  pluviometro            mm       748277.0  43.291376  11.071148
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1184  1668048.11  4795271.08  365.0         NaN
# 1185  1668048.11  4795271.08  365.0         NaN

# %%
search_for('Mensano', 'termometro')
# Out:
#        IDStazione  StazioneExtra     Nome         Comune Provincia Fiume  \
# 1186  TOS03001385              0  Mensano  Casole d'Elsa        SI   NaN
# 1187  TOS03001385              0  Mensano  Casole d'Elsa        SI   NaN
#
#        Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1186  termometro            �C       748251.0  43.291376  11.071148
# 1187  termometro            �C       748271.0  43.291376  11.071148
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1186  1668048.11  4795271.08  365.0         NaN
# 1187  1668048.11  4795271.08  365.0         NaN

# %%
search_for('Montalcinello')
# Out:
#        IDStazione  StazioneExtra           Nome     Comune Provincia Fiume  \
# 1219  TOS03002733              0  Montalcinello  Chiusdino        SI   NaN
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]   LON [o]  \
# 1219  pluviometro            mm       743957.0  43.203111  11.07662
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1219  1668735.54  4785479.63  380.0         2.0

# %%
search_for('Monticiano La Pineta', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra                  Nome      Comune Provincia  \
# 1404  TOS03002742              0  Monticiano La Pineta  Monticiano        SI
# 1405  TOS03002742              0  Monticiano La Pineta  Monticiano        SI
#
#      Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1404   NaN  pluviometro            mm       747057.0  43.134374  11.242022
# 1405   NaN  pluviometro            mm       747077.0  43.134374  11.242022
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1404  1682377.83  4778192.71  450.0         2.0
# 1405  1682377.83  4778192.71  450.0         2.0

# %%
search_for('Sovicille', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra         Nome     Comune Provincia  Fiume  \
# 1815  TOS03005707              0  Ponte Orgia  Sovicille        SI  Merse
# 2300  TOS01001379              0    Simignano  Sovicille        SI    NaN
# 2313  TOS03002761              0    Sovicille  Sovicille        SI    NaN
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1815  pluviometro            mm       747157.0  43.214645  11.258112
# 2300  pluviometro            mm       744107.0  43.292050  11.167234
# 2313  pluviometro            mm       745157.0  43.276294  11.229860
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1815  1683445.92  4787142.60    NaN         NaN
# 2300  1675841.20  4795543.72  420.0         2.0
# 2313  1680968.43  4793927.65  260.0         2.0

# %%
search_for('Ponte Orgia')
# Out:
#        IDStazione  StazioneExtra         Nome     Comune Provincia  Fiume  \
# 1814  TOS03005707              0  Ponte Orgia  Sovicille        SI  Merse
# 1815  TOS03005707              0  Ponte Orgia  Sovicille        SI  Merse
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1814    idrometro             m       747159.0  43.214645  11.258112
# 1815  pluviometro            mm       747157.0  43.214645  11.258112
#
#         GB E [m]   GB N [m]  Quota  QuotaTerra
# 1814  1683445.92  4787142.6    NaN         NaN
# 1815  1683445.92  4787142.6    NaN         NaN

# %%
search_for('Scorgiano', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra       Nome         Comune Provincia Fiume  \
# 2251  TOS11000025              0  Scorgiano  Monteriggioni        SI   NaN
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 2251  pluviometro            mm       748907.0  43.366271  11.151425
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 2251  1674346.24  4803753.45  233.0         NaN

# %%
search_for('Pentolina', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra       Nome     Comune Provincia Fiume  \
# 1553  TOS11000080              0  Pentolina  Chiusdino        SI   NaN
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1553  pluviometro            mm       751007.0  43.208502  11.179902
#
#        GB E [m]    GB N [m]  Quota  QuotaTerra
# 1553  1677110.9  4786291.82  450.0         NaN

# %%
search_for('Pentolina', 'termometro')
# Out:
#        IDStazione  StazioneExtra       Nome     Comune Provincia Fiume  \
# 1555  TOS11000080              0  Pentolina  Chiusdino        SI   NaN
#
#        Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1555  termometro            �C       751001.0  43.208502  11.179902
#
#        GB E [m]    GB N [m]  Quota  QuotaTerra
# 1555  1677110.9  4786291.82  450.0         NaN

# %%
search_for('Monteroni Arbia Biena', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra                   Nome             Comune  \
# 1361  TOS11000082              0  Monteroni Arbia Biena  Monteroni d'Arbia
#
#      Provincia Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 1361        SI   NaN  pluviometro            mm       749307.0  43.243014
#
#         LON [o]   GB E [m]    GB N [m]  Quota  QuotaTerra
# 1361  11.416887  1696251.9  4790653.72  165.0         NaN

# %%
search_for('Monteroni Arbia Biena', 'termometro')
# Out:
#        IDStazione  StazioneExtra                   Nome             Comune  \
# 1363  TOS11000082              0  Monteroni Arbia Biena  Monteroni d'Arbia
#
#      Provincia Fiume   Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 1363        SI   NaN  termometro            �C       749301.0  43.243014
#
#         LON [o]   GB E [m]    GB N [m]  Quota  QuotaTerra
# 1363  11.416887  1696251.9  4790653.72  165.0         NaN

# %%
search_for('Podere Casetta')
# Out:
#        IDStazione  StazioneExtra            Nome     Comune Provincia Fiume  \
# 1711  TOS19000681              0  Podere Casetta  Sovicille        SI   NaN
# 1712  TOS19000681              0  Podere Casetta  Sovicille        SI   NaN
# 1713  TOS19000681              0  Podere Casetta  Sovicille        SI   NaN
#
#              Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1711       freatimetro             m       763879.0  43.252262  11.225785
# 1712           qualita     microS/cm       763885.0  43.252262  11.225785
# 1713  termometro acqua            �C       763883.0  43.252262  11.225785
#
#        GB E [m]    GB N [m]   Quota  QuotaTerra
# 1711  1680708.9  4791249.82  192.57         0.0
# 1712  1680708.9  4791249.82  192.57         0.0
# 1713  1680708.9  4791249.82  192.57         0.0
