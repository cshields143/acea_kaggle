# %%
import pandas as pd
def search_for(nome, unit=None):
    in_name = df['Nome'].str.contains(nome)
    in_comune = df['Comune'].str.contains(nome)
    mydf = df[in_name | in_comune]
    return mydf if unit is None else mydf[mydf['Strumento'] == unit]
df = pd.read_csv('../../data/geo/stazioni.csv', ';')
df.head()
# Out:
#     IDStazione  StazioneExtra                            Nome        Comune  \
# 0  TOS19000601              0                              5A        Cecina
# 1  TOS19000601              0                              5A        Cecina
# 2  TOS19000601              0                              5A        Cecina
# 3  TOS11000114              0  Abbadia S. S. - Laghetto Verde  Abbadia S.S.
# 4  TOS11000114              0  Abbadia S. S. - Laghetto Verde  Abbadia S.S.
#
#   Provincia Fiume         Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 0        LI   NaN       freatimetro             m       761579.0  43.331858
# 1        LI   NaN           qualita     microS/cm       761585.0  43.331858
# 2        LI   NaN  termometro acqua            �C       761583.0  43.331858
# 3        SI   NaN        anemometro           deg       751055.0  42.883103
# 4        SI   NaN        anemometro           m/s       751056.0  42.883103
#
# ...

# %%
search_for('Piano', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra              Nome            Comune  \
# 510   TOS03002901              0  Castel del Piano  Castel del Piano
# 511   TOS03002901              0  Castel del Piano  Castel del Piano
# 1335  TOS11000051              0         Montenero  Castel del Piano
# 2255  TOS11000053              0          Seggiano  Castel del Piano
#
#      Provincia Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 510         GR   NaN  pluviometro            mm       745907.0  42.893956
# 511         GR   NaN  pluviometro            mm       745927.0  42.893956
# 1335        GR   NaN  pluviometro            mm       750407.0  42.950614
# 2255        GR   NaN  pluviometro            mm       505301.0  42.906039
#
#         LON [o]    GB E [m]    GB N [m]  Quota  QuotaTerra
# 510   11.526710  1706336.73  4752152.02  566.0         2.0
# 511   11.526710  1706336.73  4752152.02  566.0         2.0
# 1335  11.439461  1699029.90  4758233.82  193.0         NaN
# ...

# %%
search_for('Salvatore', 'pluviometro')
# Out:
#      IDStazione  StazioneExtra                  Nome                Comune  \
# 26  TOS07000001              0  Abbadia S. Salvatore  Abbadia S. Salvatore
#
#    Provincia Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 26        SI   NaN  pluviometro            mm        15201.0  42.894344
#
#       LON [o]    GB E [m]    GB N [m]  Quota  QuotaTerra
# 26  11.669369  1717984.09  4752554.84  855.0         2.0

# %%
search_for('Salvatore', 'termometro')
# Out:
#      IDStazione  StazioneExtra                  Nome                Comune  \
# 27  TOS07000001              0  Abbadia S. Salvatore  Abbadia S. Salvatore
#
#    Provincia Fiume   Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 27        SI   NaN  termometro            �C        15202.0  42.894344
#
#       LON [o]    GB E [m]    GB N [m]  Quota  QuotaTerra
# 27  11.669369  1717984.09  4752554.84  855.0         2.0

# %%
search_for('Lazzaretti')
# Out:
#       IDStazione  StazioneExtra               Nome   Comune Provincia Fiume  \
# 730  TOS29000055              0   David Lazzaretti  S.Fiora        GR   NaN
# 731  TOS29000055              1  David Lazzaretti1  S.Fiora        GR   NaN
# 732  TOS29000055              0   David Lazzaretti  S.Fiora        GR   NaN
#
#             Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 730       freatimetro             m       747109.0  42.859722  11.602777
# 731           qualita     microS/cm       747115.0  42.859722  11.602777
# 732  termometro acqua            �C       747113.0  42.859722  11.602777
#
#        GB E [m]    GB N [m]   Quota  QuotaTerra
# 730  1712665.51  4748539.55  1080.0         NaN
# 731  1712665.51  4748539.55  1080.0         NaN
# 732  1712665.51  4748539.55  1080.0         NaN

# %%
search_for('Verde', 'pluviometro')
# Out:
#     IDStazione  StazioneExtra                            Nome        Comune  \
# 8  TOS11000114              0  Abbadia S. S. - Laghetto Verde  Abbadia S.S.
#
#   Provincia Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 8        SI   NaN  pluviometro            mm       751057.0  42.883103
#
#      LON [o]    GB E [m]    GB N [m]  Quota  QuotaTerra
# 8  11.661623  1717391.08  4751286.43  910.0         2.0

# %%
search_for('Verde', 'termometro')
# Out:
#      IDStazione  StazioneExtra                            Nome        Comune  \
# 10  TOS11000114              0  Abbadia S. S. - Laghetto Verde  Abbadia S.S.
#
#    Provincia Fiume   Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 10        SI   NaN  termometro            �C       751051.0  42.883103
#
#       LON [o]    GB E [m]    GB N [m]  Quota  QuotaTerra
# 10  11.661623  1717391.08  4751286.43  910.0         2.0

# %%
search_for('Fiora', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra       Nome     Comune Provincia Fiume  \
# 2094  TOS11000052              0   S. Fiora  Arcidosso        GR   NaN
# 2095  TOS11000052              1  S. Fiora1  Arcidosso        GR   NaN
#
#         Strumento Unita' Misura  IDSensoreRete   LAT [o]    LON [o]  \
# 2094  pluviometro            mm       747257.0  42.85448  11.555793
# 2095  pluviometro            mm       747277.0  42.85448  11.555793
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 2094  1708844.63  4747839.81  813.0         2.0
# 2095  1708844.63  4747839.81  813.0         2.0

# %%
search_for('Fiora', 'termometro')
# Out:
#        IDStazione  StazioneExtra       Nome     Comune Provincia Fiume  \
# 2097  TOS11000052              0   S. Fiora  Arcidosso        GR   NaN
# 2098  TOS11000052              1  S. Fiora1  Arcidosso        GR   NaN
# 2099  TOS11000052              1  S. Fiora1  Arcidosso        GR   NaN
# 2100  TOS11000052              1  S. Fiora1  Arcidosso        GR   NaN
#
#        Strumento Unita' Misura  IDSensoreRete   LAT [o]    LON [o]  \
# 2097  termometro            �C       747251.0  42.85448  11.555793
# 2098  termometro            �C       747271.0  42.85448  11.555793
# 2099  termometro            �C       747263.0  42.85448  11.555793
# 2100  termometro            �C       747283.0  42.85448  11.555793
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 2097  1708844.63  4747839.81  813.0         2.0
# 2098  1708844.63  4747839.81  813.0         2.0
# 2099  1708844.63  4747839.81  813.0         NaN
# 2100  1708844.63  4747839.81  813.0         NaN

# %%
search_for('Fiora', 'freatimetro')
# Out:
#        IDStazione  StazioneExtra              Nome    Comune Provincia Fiume  \
# 730   TOS29000055              0  David Lazzaretti   S.Fiora        GR   NaN
# 2101  TOS20000004              0    S. Fiora 11bis  Grosseto        GR   NaN
# 2104  TOS20000003              0        S. Fiora 8  Grosseto        GR   NaN
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 730   freatimetro             m       747109.0  42.859722  11.602777
# 2101  freatimetro             m       766629.0  42.838214  11.584455
# 2104  freatimetro             m       766679.0  42.838184  11.585775
#
#         GB E [m]    GB N [m]   Quota  QuotaTerra
# 730   1712665.51  4748539.55  1080.0         NaN
# 2101  1711241.90  4746104.82   706.0         NaN
# 2104  1711349.90  4746104.82   705.0         NaN

# %%
search_for('Vetta', 'pluviometro')
# Out:
#      IDStazione  StazioneExtra                           Nome        Comune  \
# 17  TOS11000115              0   Abbadia S. S. - Vetta Amiata  Abbadia S.S.
# 24  TOS19000115              1  Abbadia S. S. - Vetta Amiata1  Abbadia S.S.
#
#    Provincia Fiume    Strumento Unita' Misura  IDSensoreRete  LAT [o]  \
# 17        SI   NaN  pluviometro            mm       747307.0  42.8901
# 24        SI   NaN  pluviometro            mm       747327.0  42.8901
#
#     LON [o]    GB E [m]    GB N [m]   Quota  QuotaTerra
# 17  11.6252  1714392.23  4751970.05  1678.0         3.0
# 24  11.6252  1714392.23  4751970.05  1678.0         3.0

# %% [markdown]
# # None of our targets appear to be in the station list!!!

# %%
search_for('Arbure')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('Bugnano')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('Ermicciolo')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('Galleria')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []
