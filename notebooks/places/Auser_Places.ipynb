# %%
import pandas as pd
def search_for(nome, unit=None):
    in_name = df['Nome'].str.contains(nome)
    in_comune = df['Comune'].str.contains(nome)
    mydf = df[in_name | in_comune]
    return mydf if unit is None else mydf[mydf['Strumento'] == unit]
df = pd.read_csv('../../data/geo/stazioni.csv', ';')

# %%
search_for('Gallicano')
# Out:
#       IDStazione  StazioneExtra       Nome     Comune Provincia Fiume  \
# 887  TOS02000299              0  Gallicano  Gallicano        LU   NaN
#
#        Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 887  pluviometro            mm       732307.0  44.064125  10.442982
#
#        GB E [m]   GB N [m]  Quota  QuotaTerra
# 887  1615595.43  4880023.1  179.0         2.0

# %%
search_for('Pontetetto')
# Out:
#        IDStazione  StazioneExtra        Nome Comune Provincia   Fiume  \
# 1868  TOS02004315              0  Pontetetto  Lucca        LU  Ozzeri
# 1869  TOS02004315              0  Pontetetto  Lucca        LU  Ozzeri
# 1870  TOS02004315              0  Pontetetto  Lucca        LU  Ozzeri
# 1871  TOS02004315              0  Pontetetto  Lucca        LU  Ozzeri
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1868    idrometro             m       730359.0  43.829653  10.469765
# 1869    idrometro             m       730379.0  43.829653  10.469765
# 1870  pluviometro            mm       730357.0  43.829653  10.469765
# 1871  pluviometro            mm       730377.0  43.829653  10.469765
#
#         GB E [m]   GB N [m]  Quota  QuotaTerra
# 1868  1618204.13  4854018.7  12.99         NaN
# 1869  1618204.13  4854018.7  12.99         0.0
# 1870  1618204.13  4854018.7  12.99         2.0
# 1871  1618204.13  4854018.7  12.99         2.0

# %%
search_for('Monte Serra', 'pluviometro')
# Out:
#        IDStazione  StazioneExtra         Nome Comune Provincia Fiume  \
# 1273  TOS01001801              0  Monte Serra  Calci        PI   NaN
# 1280  TOS11000020              0  Monte Serra  Calci        PI   NaN
# 1281  TOS11000020              0  Monte Serra  Calci        PI   NaN
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]   LON [o]  \
# 1273  pluviometro            mm        16951.0  43.751788  10.55500
# 1280  pluviometro            mm       753207.0  43.747072  10.55446
# 1281  pluviometro            mm       753227.0  43.747072  10.55446
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1273  1625219.90  4845495.82  918.0         2.0
# 1280  1625186.28  4844971.26  890.0         NaN
# 1281  1625186.28  4844971.26  890.0         NaN

# %%
search_for('Monte Serra', 'termometro')
# Out:
#        IDStazione  StazioneExtra         Nome Comune Provincia Fiume  \
# 1274  TOS01001801              0  Monte Serra  Calci        PI   NaN
# 1283  TOS11000020              0  Monte Serra  Calci        PI   NaN
#
#        Strumento Unita' Misura  IDSensoreRete    LAT [o]   LON [o]  \
# 1274  termometro            �C        16952.0  43.751788  10.55500
# 1283  termometro            �C       753201.0  43.747072  10.55446
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1274  1625219.90  4845495.82  918.0         NaN
# 1283  1625186.28  4844971.26  890.0         NaN

# %%
search_for('Orentano')
# Out:
#        IDStazione  StazioneExtra      Nome                 Comune Provincia  \
# 1453  TOS01001889              0  Orentano  Castelfranco di Sotto        PI
# 1454  TOS01001889              0  Orentano  Castelfranco di Sotto        PI
# 1455  TOS01001889              0  Orentano  Castelfranco di Sotto        PI
# 1456  TOS01001889              0  Orentano  Castelfranco di Sotto        PI
#
#      Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1453   NaN  pluviometro            mm       735757.0  43.774425  10.657082
# 1454   NaN  pluviometro            mm       735777.0  43.774425  10.657082
# 1455   NaN   termometro            �C       735751.0  43.774425  10.657082
# 1456   NaN   termometro            �C       735771.0  43.774425  10.657082
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1453  1633388.12  4848169.36   22.0         2.0
# 1454  1633388.12  4848169.36   22.0         NaN
# 1455  1633388.12  4848169.36   22.0         NaN
# ...

# %%
search_for('Mozzano', 'pluviometro')
# Out:
#       IDStazione  StazioneExtra             Nome           Comune Provincia  \
# 236  TOS02004271              0  Borgo a Mozzano  Borgo a Mozzano        LU
# 237  TOS02004271              0  Borgo a Mozzano  Borgo a Mozzano        LU
# 653  TOS02004255              0         Chifenti  Borgo a Mozzano        LU
# 654  TOS02004255              0         Chifenti  Borgo a Mozzano        LU
#
#        Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 236  Serchio  pluviometro            mm       734057.0  43.979877  10.551510
# 237  Serchio  pluviometro            mm       734077.0  43.979877  10.551510
# 653     Lima  pluviometro            mm       734007.0  44.007322  10.563969
# 654     Lima  pluviometro            mm       734027.0  44.007322  10.563969
#
#        GB E [m]    GB N [m]  Quota  QuotaTerra
# 236  1624463.43  4870823.67  100.0         2.0
# 237  1624463.43  4870823.67  100.0         2.0
# 653  1625404.90  4873890.82  103.0         2.0
# ...

# %%
search_for('Piaggione')
# Out:
#        IDStazione  StazioneExtra       Nome Comune Provincia    Fiume  \
# 1568  TOS02004284              0  Piaggione  Lucca        LU  Serchio
# 1569  TOS02004284              0  Piaggione  Lucca        LU  Serchio
# 1570  TOS02004284              0  Piaggione  Lucca        LU  Serchio
# 1571  TOS02004284              0  Piaggione  Lucca        LU  Serchio
#
#         Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1568    idrometro             m       731209.0  43.929353  10.514275
# 1569    idrometro             m       731229.0  43.929353  10.514275
# 1570  pluviometro            mm       731207.0  43.929353  10.514275
# 1571  pluviometro            mm       731227.0  43.929353  10.514275
#
#        GB E [m]    GB N [m]  Quota  QuotaTerra
# 1568  1621580.1  4865156.58   72.0         NaN
# 1569  1621580.1  4865156.58   72.0         NaN
# 1570  1621580.1  4865156.58   72.0         2.0
# 1571  1621580.1  4865156.58   72.0         2.0

# %%
search_for('Calavorno')
# Out:
#       IDStazione  StazioneExtra       Nome                 Comune Provincia  \
# 283  TOS02004195              0  Calavorno  Coreglia Antelminelli        LU
# 284  TOS02004195              0  Calavorno  Coreglia Antelminelli        LU
# 285  TOS02004195              0  Calavorno  Coreglia Antelminelli        LU
# 286  TOS02004195              0  Calavorno  Coreglia Antelminelli        LU
#
#        Fiume    Strumento Unita' Misura  IDSensoreRete   LAT [o]    LON [o]  \
# 283  Serchio    idrometro             m       733809.0  44.01975  10.535103
# 284  Serchio    idrometro             m       733829.0  44.01975  10.535103
# 285  Serchio  pluviometro            mm       733807.0  44.01975  10.535103
# 286  Serchio  pluviometro            mm       733827.0  44.01975  10.535103
#
#        GB E [m]    GB N [m]  Quota  QuotaTerra
# 283  1623065.13  4875227.79  137.0         NaN
# 284  1623065.13  4875227.79  137.0         NaN
# 285  1623065.13  4875227.79  137.0         2.0
# ...

# %%
search_for('Arcana')
# Out:
#       IDStazione  StazioneExtra          Nome              Comune Provincia  \
# 701  TOS02000372              0  Croce Arcana  Abetone Cutigliano        PT
# 702  TOS02000372              0  Croce Arcana  Abetone Cutigliano        PT
# 703  TOS02000372              0  Croce Arcana  Abetone Cutigliano        PT
# 704  TOS02000372              0  Croce Arcana  Abetone Cutigliano        PT
#
#     Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 701   NaN   anemometro           deg       733555.0  44.129883  10.781536
# 702   NaN   anemometro           m/s       733556.0  44.129883  10.781536
# 703   NaN   anemometro           m/s       733593.0  44.129883  10.781536
# 704   NaN  pluviometro            mm       733557.0  44.129883  10.781536
#
#        GB E [m]    GB N [m]   Quota  QuotaTerra
# 701  1642551.71  4887857.66  1716.0         6.0
# 702  1642551.71  4887857.66  1716.0         6.0
# 703  1642551.71  4887857.66  1716.0         6.0
# ...

# %%
search_for('Tereglio')
# Out:
#        IDStazione  StazioneExtra      Nome                 Comune Provincia  \
# 2402  TOS02000339              0  Tereglio  Coreglia Antelminelli        LU
#
#      Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 2402   NaN  pluviometro            mm       731257.0  44.059846  10.567786
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 2402  1625599.84  4879730.47  590.0         2.0

# %%
search_for('Fabbriche')
# Out:
#       IDStazione  StazioneExtra                  Nome                  Comune  \
# 772  TOS02000332              0  Fabbriche di Vallico  Fabbriche di Vergemoli
# 773  TOS02000332              0  Fabbriche di Vallico  Fabbriche di Vergemoli
# 852  TOS02000281              0          Fornovolasco  Fabbriche di Vergemoli
#
#     Provincia Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]  \
# 772        LU   NaN  pluviometro            mm       734307.0  43.999596
# 773        LU   NaN  pluviometro            mm       734327.0  43.999596
# 852        LU   NaN  pluviometro            mm       731107.0  44.028957
#
#        LON [o]    GB E [m]    GB N [m]  Quota  QuotaTerra
# 772  10.432135  1614851.27  4872840.69  345.0         2.0
# 773  10.432135  1614851.27  4872840.69  345.0         2.0
# 852  10.360547  1609057.87  4876004.70  493.0         2.0

# %%
search_for('PAG')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('DIEC')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('Moriano', 'termometro')
# Out:
#        IDStazione  StazioneExtra             Nome Comune Provincia Fiume  \
# 1776  TOS11000109              0  Ponte a Moriano  Lucca        LU   NaN
#
#        Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1776  termometro            �C       510921.0  43.890091  10.529101
#
#        GB E [m]    GB N [m]  Quota  QuotaTerra
# 1776  1622850.9  4860817.82   33.0         NaN

# %%
search_for('Botanico')
# Out:
#        IDStazione  StazioneExtra                   Nome Comune Provincia  \
# 1111  TOS02000512              0  Lucca (Orto Botanico)  Lucca        LU
# 1112  TOS02000512              0  Lucca (Orto Botanico)  Lucca        LU
# 1113  TOS02000512              0  Lucca (Orto Botanico)  Lucca        LU
# 1114  TOS02000512              0  Lucca (Orto Botanico)  Lucca        LU
#
#      Fiume    Strumento Unita' Misura  IDSensoreRete    LAT [o]   LON [o]  \
# 1111   NaN  pluviometro            mm       730157.0  43.841864  10.51086
# 1112   NaN  pluviometro            mm       730177.0  43.841864  10.51086
# 1113   NaN   termometro            �C       730151.0  43.841864  10.51086
# 1114   NaN   termometro            �C       730171.0  43.841864  10.51086
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1111  1621483.64  4855434.45   16.0         2.0
# 1112  1621483.64  4855434.45   16.0         2.0
# 1113  1621483.64  4855434.45   16.0         NaN
# ...

# %%
search_for('POL')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('CC1')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('CC2')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('CSA')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('CSAL')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('Quirico')
# Out:
#        IDStazione  StazioneExtra             Nome Comune Provincia    Fiume  \
# 1268  TOS02004291              0  Monte S.Quirico  Lucca        LU  Serchio
# 1269  TOS02004291              0  Monte S.Quirico  Lucca        LU  Serchio
#
#       Strumento Unita' Misura  IDSensoreRete    LAT [o]    LON [o]  \
# 1268  idrometro             m       730209.0  43.857255  10.506863
# 1269  idrometro             m       730229.0  43.857255  10.506863
#
#         GB E [m]    GB N [m]  Quota  QuotaTerra
# 1268  1621131.17  4857137.92   25.0         NaN
# 1269  1621131.17  4857137.92   25.0         NaN

# %%
search_for('SAL')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('CoS')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []

# %%
search_for('LT2')
# Out:
# Empty DataFrame
# Columns: [IDStazione, StazioneExtra, Nome, Comune, Provincia, Fiume, Strumento, Unita' Misura, IDSensoreRete, LAT [o], LON [o], GB E [m], GB N [m], Quota, QuotaTerra]
# Index: []
