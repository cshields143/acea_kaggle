# %%
import pandas as pd
df = pd.read_csv('geology_of_geologies.txt')

# %%
pd.set_option('display.max_colwidth',None)
df.sort_values('Station')[['Station','EnglishDescription','Period']]
# Out:
#                            Station  \
# 4   Abbadia S. S. - Laghetto Verde
# 16    Abbadia S. S. - Vetta Amiata
# 12            Abbadia S. Salvatore
# 30                        Bibbiena
# 25                       Calavorno
# 20                       Camaldoli
# 8                Castel del Piano1
# 21                         Consuma
# 29                    Croce Arcana
# 5                 David Lazzaretti
# 13            Fabbriche di Vallico
# 14                      Il Palagio
# 26                        Laterina
# 15            Le Croci (Barberino)
# 18                         Mangona
# 17                       Marcoiano
# 23                         Mensano
# 31                   Montalcinello
# 28                  Monte S.Savino
# 27                     Monte Serra
# 10            Monticiano La Pineta
# 2                         Orentano
# 22                       Pentolina
# 19                        S. Fiora
# 6                   S. Fiora 11bis
# ...

# %%
for _ in df['EnglishDescription'].unique():
    print(_, '\n')
# Out:
# Graded quartz-feldspar-micaceous sandstones, in layers of varying strength, with finer levels of siltstone
#
# Pelitic arenaceous and pelitic silitic turbidites. There are mega-bids
#
# Polygenic conglomerates and pebbles
#
# Dolomite limestones and gray dolomites brecciated and with 'cell' structure and carious dolomites (carniole)
#
# Clastogenic lava flows and block lava flows of trachydacytic composition derived from the collapse of an endogenous mega dome
#
# Yellow sands and sandstones.
#
# Quartz metaconglomerates with quartzite-filladic matrix from gray-green to purplish. The elements consist mainly of pink quartz and white or pink quartzites
#
# pelitic arenaceous member
#
# Gray-brown clay and calcilutite
#
# Member of the Calcarenites of Montegrossi
#
# Pelitic-arenaceous member
#
# ...
